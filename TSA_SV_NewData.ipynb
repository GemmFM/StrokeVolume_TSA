# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pingouin as pg

# %%
# Creación de los data frames a partir de los datos de excel
DatosV = pd.read_csv('Volumenes.csv')
DatosP = pd.read_csv('Presiones.csv')
DatosT = pd.read_csv('Periodos.csv')

# %%
# VOLUMEN EYECTADO CONTROLES
SV_c1 = DatosV[' SV_C1']
SV_c2 = DatosV[' SV_C2']
SV_c3 = DatosV[' SV_C3']
SV_c4 = DatosV[' SV_C4']
SV_c5 = DatosV[' SV_C5']
SV_c6 = DatosV[' SV_C6']
SV_c7 = DatosV[' SV_C7']
SV_c8 = DatosV[' SV_C8']
SV_c9 = DatosV[' SV_C9']
SV_c10 = DatosV[' SV_C10']
SV_c11 = DatosV[' SV_C11']
SV_c12 = DatosV[' SV_C12']
SV_c13 = DatosV[' SV_C13']
SV_c14 = DatosV[' SV_C14']

SV_C1 = SV_c1.dropna()
SV_C2 = SV_c2.dropna()
SV_C3 = SV_c3.dropna()
SV_C4 = SV_c4.dropna()
SV_C5 = SV_c5.dropna()
SV_C6 = SV_c6.dropna()
SV_C7 = SV_c7.dropna()
SV_C8 = SV_c8.dropna()
SV_C9 = SV_c9.dropna()
SV_C10 = SV_c10.dropna()
SV_C11 = SV_c11.dropna()
SV_C12 = SV_c12.dropna()
SV_C13 = SV_c13.dropna()
SV_C14 = SV_c14.dropna()

# VOLUMEN EYECTADO ANGII
SV_a1 = DatosV[' SV_A1']
SV_a2 = DatosV[' SV_A2']
SV_a3 = DatosV[' SV_A3']
SV_a4 = DatosV[' SV_A4']
SV_a5 = DatosV[' SV_A5']
SV_a6 = DatosV[' SV_A6']
SV_a7 = DatosV[' SV_A7']
SV_a8 = DatosV[' SV_A8']
SV_a9 = DatosV[' SV_A9']
SV_a10 = DatosV[' SV_A10']

SV_A1 = SV_a1.dropna()
SV_A2 = SV_a2.dropna()
SV_A3 = SV_a3.dropna()
SV_A4 = SV_a4.dropna()
SV_A5 = SV_a5.dropna()
SV_A6 = SV_a6.dropna()
SV_A7 = SV_a7.dropna()
SV_A8 = SV_a8.dropna()
SV_A9 = SV_a9.dropna()
SV_A10 = SV_a10.dropna()

# %%
# 1A DIFERENCIA SV 

# CONTROLES 
SV_C1_diff = SV_C1.diff().dropna()
SV_C2_diff = SV_C2.diff().dropna()
SV_C3_diff = SV_C3.diff().dropna()
SV_C4_diff = SV_C4.diff().dropna()
SV_C5_diff = SV_C5.diff().dropna()
SV_C6_diff = SV_C6.diff().dropna()
SV_C7_diff = SV_C7.diff().dropna()
SV_C8_diff = SV_C8.diff().dropna()
SV_C9_diff = SV_C9.diff().dropna()
SV_C10_diff = SV_C10.diff().dropna()
SV_C11_diff = SV_C11.diff().dropna()
SV_C12_diff = SV_C12.diff().dropna()
SV_C13_diff = SV_C13.diff().dropna()
SV_C14_diff = SV_C14.diff().dropna()

# ANGIOTENSINA
SV_A1_diff = SV_A1.diff().dropna()
SV_A2_diff = SV_A2.diff().dropna()
SV_A3_diff = SV_A3.diff().dropna()
SV_A4_diff = SV_A4.diff().dropna()
SV_A5_diff = SV_A5.diff().dropna()
SV_A6_diff = SV_A6.diff().dropna()
SV_A7_diff = SV_A7.diff().dropna()
SV_A8_diff = SV_A8.diff().dropna()
SV_A9_diff = SV_A9.diff().dropna()
SV_A10_diff = SV_A10.diff().dropna()

# %%
# 1a Diferencia SV Controles

fig, axs = plt.subplots(4, 4, figsize=(18, 16), sharex=True, sharey=True)

axs[0, 0].plot(SV_C1_diff, marker="o")
axs[0, 0].set_title("Control 1")

axs[0, 1].plot(SV_C2_diff, marker="o")
axs[0, 1].set_title("Control 2")

axs[0, 2].plot(SV_C3_diff, marker="o")
axs[0, 2].set_title("Control 3")

axs[0, 3].plot(SV_C4_diff, marker="o")
axs[0, 3].set_title("Control 4")

axs[1, 0].plot(SV_C5_diff, marker="o")
axs[1, 0].set_title("Control 5")

axs[1, 1].plot(SV_C6_diff, marker="o")
axs[1, 1].set_title("Control 6")

axs[1, 2].plot(SV_C7_diff, marker="o")
axs[1, 2].set_title("Control 7")

axs[1, 3].plot(SV_C8_diff, marker="o")
axs[1, 3].set_title("Control 8")

axs[2, 0].plot(SV_C9_diff, marker="o")
axs[2, 0].set_title("Control 9")

axs[2, 1].plot(SV_C10_diff, marker="o")
axs[2, 1].set_title("Control 10")

axs[2, 2].plot(SV_C11_diff, marker="o")
axs[2, 2].set_title("Control 11")

axs[2, 3].plot(SV_C12_diff, marker="o")
axs[2, 3].set_title("Control 12")

axs[3, 0].plot(SV_C13_diff, marker="o")
axs[3, 0].set_title("Control 13")

axs[3, 1].plot(SV_C14_diff, marker="o")
axs[3, 1].set_title("Control 14")

plt.tight_layout()
plt.xlim(0,60)
plt.ylim(-5,5)
plt.show()

# %%
# 1a Diferencia SV Angiotensinas

fig, axs = plt.subplots(3, 4, figsize=(18, 16), sharex=True, sharey=True)

axs[0, 0].plot(SV_A1_diff, marker="o")
axs[0, 0].set_title("ANG II 1")

axs[0, 1].plot(SV_A2_diff, marker="o")
axs[0, 1].set_title("ANG II 2")

axs[0, 2].plot(SV_A3_diff, marker="o")
axs[0, 2].set_title("ANG II 3")

axs[0, 3].plot(SV_A4_diff, marker="o")
axs[0, 3].set_title("ANG II 4")

axs[1, 0].plot(SV_A5_diff, marker="o")
axs[1, 0].set_title("ANG II 5")

axs[1, 1].plot(SV_A6_diff, marker="o")
axs[1, 1].set_title("ANG II 6")

axs[1, 2].plot(SV_A7_diff, marker="o")
axs[1, 2].set_title("ANG II 7")

axs[1, 3].plot(SV_A8_diff, marker="o")
axs[1, 3].set_title("ANG II 8")

axs[2, 0].plot(SV_A9_diff, marker="o")
axs[2, 0].set_title("ANG II 9")

axs[2, 1].plot(SV_A10_diff, marker="o")
axs[2, 1].set_title("ANG II 10")

plt.tight_layout()
plt.xlim(0,60)
plt.ylim(-5,5)
plt.show()

# %%
# Función desviación standard

cv = lambda x:np.std(x, ddof = 1)

# %%
# Coeficientes de Variación

# Controles
cv_SV_C_diff = [cv(SV_C1_diff), cv(SV_C2_diff), cv(SV_C3_diff), cv(SV_C4_diff),
           cv(SV_C5_diff), cv(SV_C6_diff), cv(SV_C7_diff), cv(SV_C8_diff),
           cv(SV_C9_diff), cv(SV_C10_diff), cv(SV_C11_diff), cv(SV_C12_diff),
           cv(SV_C13_diff), cv(SV_C14_diff)]

# Angiotensinas
cv_SV_A_diff = [cv(SV_A1_diff), cv(SV_A2_diff), cv(SV_A3_diff), cv(SV_A4_diff),
           cv(SV_A5_diff), cv(SV_A6_diff), cv(SV_A7_diff), cv(SV_A8_diff),
           cv(SV_A9_diff), cv(SV_A10_diff)]
print(cv_SV_C_diff)
print(cv_SV_A_diff)
# Out:
# [2.505209397435671, 5.786198788438196, 1.8731423446574964, 1.90187612210731, 1.5131607621714467, 1.5829948930705182, 5.770278635008974, 2.3987997966416073, 6.785480182785565, 4.159619819665717, 16.95475139022172, 6.396305584882892, 2.5025253126294, 3.7470207246799476]
# [1.1478234821736573, 1.5077144737639028, 1.683244598034283, 0.9099896535711343, 0.8620139372268849, 0.5795755446971125, 0.7303045998002397, 2.861131438109425, 1.4580017761624744, 3.6601586706028284]

# %%
# Gráfica promedio y desviación

m1 = [np.mean(cv_SV_C_diff),np.mean(cv_SV_A_diff)]
d1 = [np.std(cv_SV_C_diff),np.std(cv_SV_A_diff)]
e1 = [d1[0]/np.sqrt(14), d1[1]/np.sqrt(9)]

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.style.use('seaborn-whitegrid')

index = np.arange(2)
width = 0.7
labels = ('Controls', 'Ang_II')

fig, ax = plt.subplots()

ax.p1 = plt.bar(index, m1, width=width, color="blue",
               linewidth=2, zorder=5, alpha=0.5)

ax.errs = plt.errorbar(index, m1, yerr=e1, fmt='.k')

plt.xticks(index, labels)

plt.ylabel('Average of Standard Desviation 1a diff')
plt.show()

# %%
#pg.ttest(x = cv_SV_C, y = cv_SV_A, paired=False, alternative='two-sided', correction='auto', r=0.707, confidence=0.95)

pg.ttest(x = cv_SV_C_diff, y = cv_SV_A_diff)
# Out:
#                T        dof alternative     p-val         CI95%  cohen-d  \
# T-test  2.693445  15.140188   two-sided  0.016573  [0.63, 5.41]  0.95551
#
#          BF10     power
# T-test  4.181  0.597316

# %%
# Verificar si la series son estacionarias
# Si p-value es menor que 5% se puede garantizar la estacionariedad de la serie

# CONTROLES
aFuller_SV_C1 = adfuller(SV_C1_diff) 
print('ADF Statistics SVC1: %f' %aFuller_SV_C1[0])
print('p-value SVC1: %f' %aFuller_SV_C1[1]) 

aFuller_SV_C2 = adfuller(SV_C2_diff) 
print('ADF Statistics SVC2: %f' %aFuller_SV_C2[0])
print('p-value SVC2: %f' %aFuller_SV_C2[1])

aFuller_SV_C3 = adfuller(SV_C3_diff) 
print('ADF Statistics SVC3: %f' %aFuller_SV_C3[0])
print('p-value SVC3: %f' %aFuller_SV_C3[1])

aFuller_SV_C4 = adfuller(SV_C4_diff) 
print('ADF Statistics SVC4: %f' %aFuller_SV_C4[0])
print('p-value SVC4: %f' %aFuller_SV_C4[1])

aFuller_SV_C5 = adfuller(SV_C5_diff) 
print('ADF Statistics SVC5: %f' %aFuller_SV_C5[0])
print('p-value SVC5: %f' %aFuller_SV_C5[1])

aFuller_SV_C6 = adfuller(SV_C6_diff) 
print('ADF Statistics SVC6: %f' %aFuller_SV_C6[0])
print('p-value SVC6: %f' %aFuller_SV_C6[1])

aFuller_SV_C7 = adfuller(SV_C7_diff) 
print('ADF Statistics SVC7: %f' %aFuller_SV_C7[0])
print('p-value SVC7: %f' %aFuller_SV_C7[1])

aFuller_SV_C8 = adfuller(SV_C8_diff) 
print('ADF Statistics SVC8: %f' %aFuller_SV_C8[0])
print('p-value SVC8: %f' %aFuller_SV_C8[1])

aFuller_SV_C9 = adfuller(SV_C9_diff) 
print('ADF Statistics SVC9: %f' %aFuller_SV_C9[0])
print('p-value SVC9: %f' %aFuller_SV_C9[1])

aFuller_SV_C10 = adfuller(SV_C10_diff) 
print('ADF Statistics SVC10: %f' %aFuller_SV_C10[0])
print('p-value SVC10: %f' %aFuller_SV_C10[1])

aFuller_SV_C11 = adfuller(SV_C11_diff) 
print('ADF Statistics SVC11: %f' %aFuller_SV_C11[0])
print('p-value SVC11: %f' %aFuller_SV_C11[1])

aFuller_SV_C12 = adfuller(SV_C12_diff) 
print('ADF Statistics SVC12: %f' %aFuller_SV_C12[0])
print('p-value SVC12: %f' %aFuller_SV_C12[1])

aFuller_SV_C13 = adfuller(SV_C13_diff) 
print('ADF Statistics SVC13: %f' %aFuller_SV_C13[0])
print('p-value SVC13: %f' %aFuller_SV_C13[1])

aFuller_SV_C14 = adfuller(SV_C14_diff) 
print('ADF Statistics SVC14: %f' %aFuller_SV_C14[0])
print('p-value SVC14: %f' %aFuller_SV_C14[1])

# ANGIOTENSINAS
aFuller_SV_A1 = adfuller(SV_A1_diff) 
print('ADF Statistics SVA1: %f' %aFuller_SV_A1[0])
print('p-value SVA1: %f' %aFuller_SV_A1[1]) 

aFuller_SV_A2 = adfuller(SV_A2_diff) 
print('ADF Statistics SVA2: %f' %aFuller_SV_A2[0])
print('p-value SVA2: %f' %aFuller_SV_A2[1])

aFuller_SV_A3 = adfuller(SV_A3_diff) 
print('ADF Statistics SVA3: %f' %aFuller_SV_A3[0])
print('p-value SVA3: %f' %aFuller_SV_A3[1])

aFuller_SV_A4 = adfuller(SV_A4_diff) 
print('ADF Statistics SVA4: %f' %aFuller_SV_A4[0])
print('p-value SVA4: %f' %aFuller_SV_A4[1])

aFuller_SV_A5 = adfuller(SV_A5_diff) 
print('ADF Statistics SVA5: %f' %aFuller_SV_A5[0])
print('p-value SVA5: %f' %aFuller_SV_A5[1])

aFuller_SV_A6 = adfuller(SV_A6_diff) 
print('ADF Statistics SVA6: %f' %aFuller_SV_A6[0])
print('p-value SVA6: %f' %aFuller_SV_A6[1])

aFuller_SV_A7 = adfuller(SV_A7_diff) 
print('ADF Statistics SVA7: %f' %aFuller_SV_A7[0])
print('p-value SVA7: %f' %aFuller_SV_A7[1])

aFuller_SV_A8 = adfuller(SV_A8_diff) 
print('ADF Statistics SVA8: %f' %aFuller_SV_A8[0])
print('p-value SVA8: %f' %aFuller_SV_A8[1])

aFuller_SV_A9 = adfuller(SV_A9_diff) 
print('ADF Statistics SVA9: %f' %aFuller_SV_A9[0])
print('p-value SVA9: %f' %aFuller_SV_A9[1])

aFuller_SV_A10 = adfuller(SV_A10_diff) 
print('ADF Statistics SVA10: %f' %aFuller_SV_A10[0])
print('p-value SVA10: %f' %aFuller_SV_A10[1])
# Out:
# ADF Statistics SVC1: -5.991449
# p-value SVC1: 0.000000
# ADF Statistics SVC2: -5.638463
# p-value SVC2: 0.000001
# ADF Statistics SVC3: -6.414872
# p-value SVC3: 0.000000
# ADF Statistics SVC4: -6.427276
# p-value SVC4: 0.000000
# ADF Statistics SVC5: -7.825615
# p-value SVC5: 0.000000
# ADF Statistics SVC6: -6.427267
# p-value SVC6: 0.000000
# ADF Statistics SVC7: -7.277137
# p-value SVC7: 0.000000
# ADF Statistics SVC8: -7.006166
# p-value SVC8: 0.000000
# ADF Statistics SVC9: -8.988290
# p-value SVC9: 0.000000
# ADF Statistics SVC10: -6.845973
# p-value SVC10: 0.000000
# ADF Statistics SVC11: -5.653069
# p-value SVC11: 0.000001
# ADF Statistics SVC12: -4.221038
# p-value SVC12: 0.000607
# ADF Statistics SVC13: -7.717493
# p-value SVC13: 0.000000
# ADF Statistics SVC14: -2.676225
# p-value SVC14: 0.078244
# ADF Statistics SVA1: -3.844082
# p-value SVA1: 0.002487
# ADF Statistics SVA2: -5.703485
# p-value SVA2: 0.000001
# ADF Statistics SVA3: -14.512606
# p-value SVA3: 0.000000
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C1
# El orden del modelo se escoge considerando los resultados de las funciones de autocorrelación.

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C1_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C1_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C1, lags: {}'.format(lags))
plt.show()

model_SVC1_diff = AutoReg(SV_C1_diff, 12)
SVC1_ARdiff = model_SVC1_diff.fit()
print(SVC1_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C1   No. Observations:                   49
# Model:                    AutoReg(12)   Log Likelihood                 -64.886
# Method:               Conditional MLE   S.D. of innovations              1.398
# Date:                Wed, 21 Sep 2022   AIC                            157.771
# Time:                        15:04:18   BIC                            180.324
# Sample:                            12   HQIC                           165.722
#                                    49
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3229      0.237      1.361      0.173      -0.142       0.788
#  SV_C1.L1     -1.0470      0.139     -7.518      0.000      -1.320      -0.774
#  SV_C1.L2     -1.1404      0.162     -7.019      0.000      -1.459      -0.822
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C2

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C2_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C2_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C2, lags: {}'.format(lags))
plt.show()

model_SVC2_diff = AutoReg(SV_C2_diff, 10)
SVC2_ARdiff = model_SVC2_diff.fit()
print(SVC2_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C2   No. Observations:                   46
# Model:                    AutoReg(10)   Log Likelihood                 -90.686
# Method:               Conditional MLE   S.D. of innovations              3.005
# Date:                Wed, 21 Sep 2022   AIC                            205.372
# Time:                        15:04:18   BIC                            224.375
# Sample:                            10   HQIC                           212.005
#                                    46
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4778      0.511     -0.936      0.349      -1.479       0.523
#  SV_C2.L1     -0.9819      0.156     -6.311      0.000      -1.287      -0.677
#  SV_C2.L2     -1.2651      0.219     -5.780      0.000      -1.694      -0.836
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C3

# %%
lags = 30
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C3_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C3_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C3, lags: {}'.format(lags))
plt.show()

model_SVC3_diff = AutoReg(SV_C3_diff, 17)
SVC3_ARdiff = model_SVC3_diff.fit()
print(SVC3_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C3   No. Observations:                   72
# Model:                    AutoReg(17)   Log Likelihood                 -93.871
# Method:               Conditional MLE   S.D. of innovations              1.334
# Date:                Wed, 21 Sep 2022   AIC                            225.742
# Time:                        15:04:19   BIC                            263.881
# Sample:                            17   HQIC                           240.491
#                                    72
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1039      0.181      0.574      0.566      -0.251       0.459
#  SV_C3.L1     -0.5031      0.136     -3.699      0.000      -0.770      -0.237
#  SV_C3.L2     -0.4292      0.146     -2.933      0.003      -0.716      -0.142
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C4

# %%
lags = 25
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C4_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C4_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C4, lags: {}'.format(lags))
plt.show()

model_SVC4_diff = AutoReg(SV_C4_diff, 17)
SVC4_ARdiff = model_SVC4_diff.fit()
print(SVC4_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C4   No. Observations:                   72
# Model:                    AutoReg(17)   Log Likelihood                 -69.027
# Method:               Conditional MLE   S.D. of innovations              0.849
# Date:                Wed, 21 Sep 2022   AIC                            176.053
# Time:                        15:04:19   BIC                            214.193
# Sample:                            17   HQIC                           190.802
#                                    72
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3281      0.116     -2.830      0.005      -0.555      -0.101
#  SV_C4.L1     -0.6936      0.094     -7.344      0.000      -0.879      -0.508
#  SV_C4.L2     -0.6739      0.077     -8.697      0.000      -0.826      -0.522
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C5

# %%
lags = 25
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C5_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C5_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C5, lags: {}'.format(lags))
plt.show()

model_SVC5_diff = AutoReg(SV_C5_diff, 12)
SVC5_ARdiff = model_SVC5_diff.fit()
print(SVC5_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C5   No. Observations:                   72
# Model:                    AutoReg(12)   Log Likelihood                 -76.470
# Method:               Conditional MLE   S.D. of innovations              0.866
# Date:                Wed, 21 Sep 2022   AIC                            180.939
# Time:                        15:04:19   BIC                            210.260
# Sample:                            12   HQIC                           192.408
#                                    72
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0029      0.112     -0.026      0.979      -0.223       0.217
#  SV_C5.L1     -0.8439      0.102     -8.242      0.000      -1.045      -0.643
#  SV_C5.L2     -0.8363      0.111     -7.520      0.000      -1.054      -0.618
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C6

# %%
lags = 25
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C6_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C6_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C6, lags: {}'.format(lags))
plt.show()

model_SVC6_diff = AutoReg(SV_C6_diff, 21)
SVC6_ARdiff = model_SVC6_diff.fit()
print(SVC6_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C6   No. Observations:                   80
# Model:                    AutoReg(21)   Log Likelihood                 -67.067
# Method:               Conditional MLE   S.D. of innovations              0.754
# Date:                Wed, 21 Sep 2022   AIC                            180.134
# Time:                        15:04:20   BIC                            227.917
# Sample:                            21   HQIC                           198.787
#                                    80
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0496      0.101     -0.490      0.624      -0.248       0.149
#  SV_C6.L1     -0.6154      0.111     -5.562      0.000      -0.832      -0.399
#  SV_C6.L2     -0.6789      0.104     -6.532      0.000      -0.883      -0.475
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C7

# %%
lags = 15
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C7_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C7_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C7, lags: {}'.format(lags))
plt.show()

model_SVC7_diff = AutoReg(SV_C7_diff, 2)
SVC7_ARdiff = model_SVC7_diff.fit()
print(SVC7_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C7   No. Observations:                   40
# Model:                     AutoReg(2)   Log Likelihood                -113.927
# Method:               Conditional MLE   S.D. of innovations              4.851
# Date:                Wed, 21 Sep 2022   AIC                            235.854
# Time:                        15:04:20   BIC                            242.404
# Sample:                             2   HQIC                           238.184
#                                    40
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0777      0.787      0.099      0.921      -1.465       1.620
#  SV_C7.L1     -0.6205      0.152     -4.091      0.000      -0.918      -0.323
#  SV_C7.L2     -0.3456      0.152     -2.276      0.023      -0.643      -0.048
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C8

# %%
lags = 14
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C8_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C8_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C8, lags: {}'.format(lags))
plt.show()

model_SVC8_diff = AutoReg(SV_C8_diff, 2)
SVC8_ARdiff = model_SVC8_diff.fit()
print(SVC8_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C8   No. Observations:                   30
# Model:                     AutoReg(2)   Log Likelihood                 -56.512
# Method:               Conditional MLE   S.D. of innovations              1.821
# Date:                Wed, 21 Sep 2022   AIC                            121.024
# Time:                        15:04:21   BIC                            126.352
# Sample:                             2   HQIC                           122.653
#                                    30
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1098      0.344     -0.319      0.750      -0.785       0.565
#  SV_C8.L1     -0.0232      0.155     -0.150      0.881      -0.327       0.281
#  SV_C8.L2     -0.5219      0.143     -3.658      0.000      -0.802      -0.242
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C9

# %%
lags = 19
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C9_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C9_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C9, lags: {}'.format(lags))
plt.show()

model_SVC9_diff = AutoReg(SV_C9_diff, 2)
SVC9_ARdiff = model_SVC9_diff.fit()
print(SVC9_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_C9   No. Observations:                   41
# Model:                     AutoReg(2)   Log Likelihood                -120.944
# Method:               Conditional MLE   S.D. of innovations              5.377
# Date:                Wed, 21 Sep 2022   AIC                            249.888
# Time:                        15:04:21   BIC                            256.542
# Sample:                             2   HQIC                           252.275
#                                    41
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3977      0.862     -0.461      0.645      -2.087       1.292
#  SV_C9.L1     -0.5525      0.135     -4.082      0.000      -0.818      -0.287
#  SV_C9.L2     -0.5309      0.134     -3.948      0.000      -0.794      -0.267
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C10

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C10_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C10_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C10, lags: {}'.format(lags))
plt.show()

model_SVC10_diff = AutoReg(SV_C10_diff, 17)
SVC10_ARdiff = model_SVC10_diff.fit()
print(SVC10_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                 SV_C10   No. Observations:                   56
# Model:                    AutoReg(17)   Log Likelihood                -100.900
# Method:               Conditional MLE   S.D. of innovations              3.216
# Date:                Wed, 21 Sep 2022   AIC                            239.800
# Time:                        15:04:21   BIC                            271.408
# Sample:                            17   HQIC                           251.141
#                                    56
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.3829      0.520      0.736      0.462      -0.637       1.403
#  SV_C10.L1     -0.0161      0.151     -0.107      0.915      -0.312       0.280
#  SV_C10.L2     -0.2290      0.167     -1.373      0.170      -0.556       0.098
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C11

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C11_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C11_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C11, lags: {}'.format(lags))
plt.show()

model_SVC11_diff = AutoReg(SV_C11_diff, 16)
SVC11_ARdiff = model_SVC11_diff.fit()
print(SVC11_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                 SV_C11   No. Observations:                   72
# Model:                    AutoReg(16)   Log Likelihood                -204.338
# Method:               Conditional MLE   S.D. of innovations              9.299
# Date:                Wed, 21 Sep 2022   AIC                            444.677
# Time:                        15:04:22   BIC                            481.133
# Sample:                            16   HQIC                           458.811
#                                    72
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.8325      1.260     -0.661      0.509      -3.303       1.638
#  SV_C11.L1     -0.5537      0.117     -4.753      0.000      -0.782      -0.325
#  SV_C11.L2     -1.0338      0.133     -7.751      0.000      -1.295      -0.772
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C12

# %%
lags = 15
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C12_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C12_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C12, lags: {}'.format(lags))
plt.show()

model_SVC12_diff = AutoReg(SV_C12_diff, 10)
SVC12_ARdiff = model_SVC12_diff.fit()
print(SVC12_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                 SV_C12   No. Observations:                   49
# Model:                    AutoReg(10)   Log Likelihood                -115.109
# Method:               Conditional MLE   S.D. of innovations              4.630
# Date:                Wed, 21 Sep 2022   AIC                            254.217
# Time:                        15:04:22   BIC                            274.180
# Sample:                            10   HQIC                           261.380
#                                    49
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1545      0.755      0.205      0.838      -1.326       1.635
#  SV_C12.L1     -0.7872      0.154     -5.108      0.000      -1.089      -0.485
#  SV_C12.L2     -0.1720      0.198     -0.869      0.385      -0.560       0.216
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C13

# %%
lags = 25
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C13_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C13_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C13, lags: {}'.format(lags))
plt.show()

model_SVC13_diff = AutoReg(SV_C13_diff, 13)
SVC13_ARdiff = model_SVC13_diff.fit()
print(SVC13_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                 SV_C13   No. Observations:                   76
# Model:                    AutoReg(13)   Log Likelihood                 -95.613
# Method:               Conditional MLE   S.D. of innovations              1.104
# Date:                Wed, 21 Sep 2022   AIC                            221.226
# Time:                        15:04:23   BIC                            253.373
# Sample:                            13   HQIC                           233.869
#                                    76
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.2484      0.144     -1.721      0.085      -0.531       0.035
#  SV_C13.L1     -0.9222      0.104     -8.904      0.000      -1.125      -0.719
#  SV_C13.L2     -0.8019      0.121     -6.625      0.000      -1.039      -0.565
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV C14

# %%
lags = 30
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_C14_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_C14_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV C14, lags: {}'.format(lags))
plt.show()

model_SVC14_diff = AutoReg(SV_C14_diff, 20)
SVC14_ARdiff = model_SVC14_diff.fit()
print(SVC14_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                 SV_C14   No. Observations:                   74
# Model:                    AutoReg(20)   Log Likelihood                 -56.498
# Method:               Conditional MLE   S.D. of innovations              0.689
# Date:                Wed, 21 Sep 2022   AIC                            156.996
# Time:                        15:04:23   BIC                            200.754
# Sample:                            20   HQIC                           173.872
#                                    74
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0756      0.096      0.788      0.431      -0.112       0.264
#  SV_C14.L1     -0.9096      0.126     -7.206      0.000      -1.157      -0.662
#  SV_C14.L2     -0.5192      0.173     -3.009      0.003      -0.857      -0.181
# ...

# %%
# Raices minimas

drt_SVC1 = 1/min(abs(SVC1_ARdiff.roots))
drt_SVC2 = 1/min(abs(SVC2_ARdiff.roots))
drt_SVC3 = 1/min(abs(SVC3_ARdiff.roots))
drt_SVC4 = 1/min(abs(SVC4_ARdiff.roots))
drt_SVC5 = 1/min(abs(SVC5_ARdiff.roots))
drt_SVC6 = 1/min(abs(SVC6_ARdiff.roots))
drt_SVC7 = 1/min(abs(SVC7_ARdiff.roots))
drt_SVC8 = 1/min(abs(SVC8_ARdiff.roots))
drt_SVC9 = 1/min(abs(SVC9_ARdiff.roots))
drt_SVC10 = 1/min(abs(SVC10_ARdiff.roots))
drt_SVC11 = 1/min(abs(SVC11_ARdiff.roots))
drt_SVC12 = 1/min(abs(SVC12_ARdiff.roots))
drt_SVC13 = 1/min(abs(SVC13_ARdiff.roots))
drt_SVC14 = 1/min(abs(SVC14_ARdiff.roots))


drt_SVC = [drt_SVC1, drt_SVC2, drt_SVC3, drt_SVC4, drt_SVC5,
          drt_SVC6, drt_SVC7, drt_SVC8, drt_SVC9, drt_SVC10,
          drt_SVC11, drt_SVC12, drt_SVC13, drt_SVC14]
print(drt_SVC)
# Out:
# [0.9823039995413124, 0.982594642903376, 0.9969386193895472, 0.9964243519480958, 0.9903425987150324, 0.9935380675348446, 0.5878986128443576, 0.7224520363750029, 0.7286054916645681, 0.9881446370552105, 0.991403704115972, 0.9787495667408597, 0.9958506625268936, 0.9978241585244523]

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A1

# %%
lags = 25
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A1_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A1_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A1, lags: {}'.format(lags))
plt.show()

model_SVA1_diff = AutoReg(SV_A1_diff, 19)
SVA1_ARdiff = model_SVA1_diff.fit()
print(SVA1_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A1   No. Observations:                   52
# Model:                    AutoReg(19)   Log Likelihood                 -13.395
# Method:               Conditional MLE   S.D. of innovations              0.363
# Date:                Wed, 21 Sep 2022   AIC                             68.790
# Time:                        15:04:24   BIC                            100.217
# Sample:                            19   HQIC                            79.364
#                                    52
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1661      0.067      2.477      0.013       0.035       0.297
#  SV_A1.L1     -0.6444      0.130     -4.954      0.000      -0.899      -0.389
#  SV_A1.L2     -0.0968      0.142     -0.680      0.497      -0.376       0.182
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A2

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A2_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A2_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A2, lags: {}'.format(lags))
plt.show()

model_SVA2_diff = AutoReg(SV_A2_diff, 11)
SVA2_ARdiff = model_SVA2_diff.fit()
print(SVA2_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A2   No. Observations:                   48
# Model:                    AutoReg(11)   Log Likelihood                 -59.794
# Method:               Conditional MLE   S.D. of innovations              1.218
# Date:                Wed, 21 Sep 2022   AIC                            145.588
# Time:                        15:04:25   BIC                            166.530
# Sample:                            11   HQIC                           152.971
#                                    48
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0412      0.210      0.197      0.844      -0.370       0.452
#  SV_A2.L1      0.2410      0.152      1.588      0.112      -0.056       0.539
#  SV_A2.L2     -0.2783      0.157     -1.772      0.076      -0.586       0.030
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A3

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A3_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A3_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A3, lags: {}'.format(lags))
plt.show()

model_SVA3_diff = AutoReg(SV_A3_diff, 10)
SVA3_ARdiff = model_SVA3_diff.fit()
print(SVA3_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A3   No. Observations:                   46
# Model:                    AutoReg(10)   Log Likelihood                 -52.296
# Method:               Conditional MLE   S.D. of innovations              1.034
# Date:                Wed, 21 Sep 2022   AIC                            128.592
# Time:                        15:04:28   BIC                            147.594
# Sample:                            10   HQIC                           135.224
#                                    46
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1317      0.174      0.757      0.449      -0.209       0.472
#  SV_A3.L1     -0.7906      0.171     -4.631      0.000      -1.125      -0.456
#  SV_A3.L2     -0.2063      0.214     -0.962      0.336      -0.627       0.214
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A4

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A4_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A4_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A4, lags: {}'.format(lags))
plt.show()

model_SVA4_diff = AutoReg(SV_A4_diff, 14)
SVA4_ARdiff = model_SVA4_diff.fit()
print(SVA4_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A4   No. Observations:                   67
# Model:                    AutoReg(14)   Log Likelihood                 -49.947
# Method:               Conditional MLE   S.D. of innovations              0.621
# Date:                Wed, 21 Sep 2022   AIC                            131.895
# Time:                        15:04:54   BIC                            163.419
# Sample:                            14   HQIC                           144.017
#                                    67
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0923      0.094     -0.982      0.326      -0.276       0.092
#  SV_A4.L1     -0.5535      0.135     -4.104      0.000      -0.818      -0.289
#  SV_A4.L2     -0.4766      0.150     -3.188      0.001      -0.770      -0.184
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A5

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A5_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A5_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A5, lags: {}'.format(lags))
plt.show()

model_SVA5_diff = AutoReg(SV_A5_diff, 4)
SVA5_ARdiff = model_SVA5_diff.fit()
print(SVA5_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A5   No. Observations:                   72
# Model:                     AutoReg(4)   Log Likelihood                 -79.815
# Method:               Conditional MLE   S.D. of innovations              0.783
# Date:                Wed, 21 Sep 2022   AIC                            171.629
# Time:                        15:05:04   BIC                            184.946
# Sample:                             4   HQIC                           176.906
#                                    72
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0111      0.095      0.117      0.907      -0.175       0.197
#  SV_A5.L1     -0.4046      0.118     -3.430      0.001      -0.636      -0.173
#  SV_A5.L2     -0.3204      0.122     -2.631      0.009      -0.559      -0.082
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A6

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A6_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A6_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A6, lags: {}'.format(lags))
plt.show()

model_SVA6_diff = AutoReg(SV_A6_diff, 15)
SVA6_ARdiff = model_SVA6_diff.fit()
print(SVA6_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A6   No. Observations:                   72
# Model:                    AutoReg(15)   Log Likelihood                 -18.320
# Method:               Conditional MLE   S.D. of innovations              0.334
# Date:                Wed, 21 Sep 2022   AIC                             70.640
# Time:                        15:05:08   BIC                            105.372
# Sample:                            15   HQIC                            84.138
#                                    72
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0762      0.046      1.667      0.095      -0.013       0.166
#  SV_A6.L1     -0.7875      0.126     -6.261      0.000      -1.034      -0.541
#  SV_A6.L2     -0.9335      0.150     -6.232      0.000      -1.227      -0.640
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A7

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A7_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A7_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A7, lags: {}'.format(lags))
plt.show()

model_SVA7_diff = AutoReg(SV_A7_diff, 1)
SVA7_ARdiff = model_SVA7_diff.fit()
print(SVA7_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A7   No. Observations:                   90
# Model:                     AutoReg(1)   Log Likelihood                 -86.661
# Method:               Conditional MLE   S.D. of innovations              0.641
# Date:                Wed, 21 Sep 2022   AIC                            179.321
# Time:                        15:05:12   BIC                            186.787
# Sample:                             1   HQIC                           182.330
#                                    90
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0363      0.068     -0.534      0.594      -0.169       0.097
#  SV_A7.L1     -0.4752      0.093     -5.110      0.000      -0.657      -0.293
#                                     Roots
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A8

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A8_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A8_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A8, lags: {}'.format(lags))
plt.show()

model_SVA8_diff = AutoReg(SV_A8_diff, 5)
SVA8_ARdiff = model_SVA8_diff.fit()
print(SVA8_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A8   No. Observations:                   69
# Model:                     AutoReg(5)   Log Likelihood                -139.942
# Method:               Conditional MLE   S.D. of innovations              2.155
# Date:                Wed, 21 Sep 2022   AIC                            293.884
# Time:                        15:05:20   BIC                            308.996
# Sample:                             5   HQIC                           299.838
#                                    69
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0223      0.274     -0.082      0.935      -0.559       0.514
#  SV_A8.L1     -0.7016      0.126     -5.555      0.000      -0.949      -0.454
#  SV_A8.L2     -0.8277      0.167     -4.945      0.000      -1.156      -0.500
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A9

# %%
lags = 20
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A9_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A9_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A9, lags: {}'.format(lags))
plt.show()

model_SVA9_diff = AutoReg(SV_A9_diff, 6)
SVA9_ARdiff = model_SVA9_diff.fit()
print(SVA9_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                  SV_A9   No. Observations:                  100
# Model:                     AutoReg(6)   Log Likelihood                -114.110
# Method:               Conditional MLE   S.D. of innovations              0.815
# Date:                Wed, 21 Sep 2022   AIC                            244.221
# Time:                        15:05:30   BIC                            264.567
# Sample:                             6   HQIC                           252.439
#                                   100
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0036      0.084     -0.043      0.966      -0.168       0.161
#  SV_A9.L1     -0.9279      0.096     -9.646      0.000      -1.116      -0.739
#  SV_A9.L2     -0.8689      0.130     -6.660      0.000      -1.125      -0.613
# ...

# %% [markdown]
# ###### PACF, ACF  y AR Model 1a Diff SV A10

# %%
lags = 25
f, axarr = plt.subplots(1, 2, figsize=(20,5))
plot_pacf(SV_A10_diff, method='ols', lags=lags, ax=axarr[0].axes)
plot_acf(SV_A10_diff, lags=lags, ax=axarr[1].axes)
plt.suptitle('1a Diff SV A10, lags: {}'.format(lags))
plt.show()

model_SVA10_diff = AutoReg(SV_A10_diff, 1)
SVA10_ARdiff = model_SVA10_diff.fit()
print(SVA10_ARdiff.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                 SV_A10   No. Observations:                   61
# Model:                     AutoReg(1)   Log Likelihood                 -58.538
# Method:               Conditional MLE   S.D. of innovations              0.642
# Date:                Wed, 21 Sep 2022   AIC                            123.077
# Time:                        15:05:54   BIC                            129.360
# Sample:                             1   HQIC                           125.534
#                                    61
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0505      0.083      0.610      0.542      -0.112       0.213
#  SV_A10.L1    -0.9874      0.023    -43.086      0.000      -1.032      -0.943
#                                     Roots
# ...

# %%
# Raices minimas
drt_SVA1 = 1/min(abs(SVA1_ARdiff.roots))
drt_SVA2 = 1/min(abs(SVA2_ARdiff.roots))
drt_SVA3 = 1/min(abs(SVA3_ARdiff.roots))
drt_SVA4 = 1/min(abs(SVA4_ARdiff.roots))
drt_SVA5 = 1/min(abs(SVA5_ARdiff.roots))
drt_SVA6 = 1/min(abs(SVA6_ARdiff.roots))
drt_SVA7 = 1/min(abs(SVA7_ARdiff.roots))
drt_SVA8 = 1/min(abs(SVA8_ARdiff.roots))
drt_SVA9 = 1/min(abs(SVA9_ARdiff.roots))
drt_SVA10 = 1/min(abs(SVA10_ARdiff.roots))


drt_SVA = [drt_SVA1, drt_SVA2, drt_SVA3, drt_SVA4, drt_SVA5,
          drt_SVA6, drt_SVA7, drt_SVA8, drt_SVA9]
print(drt_SVA)
# Out:
# [0.9931291333257065, 0.978585270854405, 0.9753110933288659, 0.971341979296471, 0.74705680837029, 0.9854987663100495, 0.475203596335854, 0.867535947169392, 0.8473802483542221]

# %% [markdown]
# ###### Plot Dynamic Response Time

# %%
m1 = [np.mean(drt_SVC),np.mean(drt_SVA)]
d1 = [np.std(drt_SVC),np.std(drt_SVA)]
e1 = [d1[0]/np.sqrt(14), d1[1]/np.sqrt(9)]

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.style.use('seaborn-whitegrid')


index = np.arange(2)
width = 0.7
labels = ('Controls', 'Ang_II')

fig, ax = plt.subplots()
ax.p1 = plt.bar(index, m1, width=width, color="blue",
               linewidth=2, zorder=5, alpha=0.5)
ax.errs = plt.errorbar(index, m1, yerr=e1, fmt='.k')

plt.xticks(index, labels)

plt.ylabel('Average of Maximum Dynamic Response Time 1a diff SV')
plt.ylim(0.6,1)
plt.show()

pg.ttest(x = drt_SVC, y = drt_SVA, paired=False, alternative='two-sided', correction='auto', confidence=0.95)
# Out:
#                T       dof alternative     p-val         CI95%   cohen-d  \
# T-test  0.778374  14.39135   two-sided  0.448958  [-0.09, 0.2]  0.349943
#
#          BF10     power
# T-test  0.478  0.122482

# %%
model_SVC1_diff = AutoReg(SV_C1_diff, 2)
SVC1_ARdiff = model_SVC1_diff.fit()

model_SVC2_diff = AutoReg(SV_C2_diff, 2)
SVC2_ARdiff = model_SVC2_diff.fit()

model_SVC3_diff = AutoReg(SV_C3_diff, 2)
SVC3_ARdiff = model_SVC3_diff.fit()

model_SVC4_diff = AutoReg(SV_C4_diff, 2)
SVC4_ARdiff = model_SVC4_diff.fit()

model_SVC5_diff = AutoReg(SV_C2_diff, 2)
SVC5_ARdiff = model_SVC5_diff.fit()

model_SVC6_diff = AutoReg(SV_C6_diff, 2)
SVC6_ARdiff = model_SVC6_diff.fit()

model_SVC7_diff = AutoReg(SV_C7_diff, 2)
SVC7_ARdiff = model_SVC7_diff.fit()

model_SVC8_diff = AutoReg(SV_C8_diff, 2)
SVC8_ARdiff = model_SVC8_diff.fit()

model_SVC9_diff = AutoReg(SV_C9_diff, 2)
SVC9_ARdiff = model_SVC9_diff.fit()

model_SVC10_diff = AutoReg(SV_C10_diff, 2)
SVC10_ARdiff = model_SVC10_diff.fit()

model_SVC11_diff = AutoReg(SV_C11_diff, 2)
SVC11_ARdiff = model_SVC11_diff.fit()

model_SVC12_diff = AutoReg(SV_C12_diff, 2)
SVC12_ARdiff = model_SVC12_diff.fit()

model_SVC13_diff = AutoReg(SV_C13_diff, 2)
SVC13_ARdiff = model_SVC13_diff.fit()

model_SVC14_diff = AutoReg(SV_C14_diff, 2)
SVC14_ARdiff = model_SVC14_diff.fit()

# Raices minimas

drt_SVC1 = 1/min(abs(SVC1_ARdiff.roots))
drt_SVC2 = 1/min(abs(SVC2_ARdiff.roots))
drt_SVC3 = 1/min(abs(SVC3_ARdiff.roots))
drt_SVC4 = 1/min(abs(SVC4_ARdiff.roots))
drt_SVC5 = 1/min(abs(SVC5_ARdiff.roots))
drt_SVC6 = 1/min(abs(SVC6_ARdiff.roots))
drt_SVC7 = 1/min(abs(SVC7_ARdiff.roots))
drt_SVC8 = 1/min(abs(SVC8_ARdiff.roots))
drt_SVC9 = 1/min(abs(SVC9_ARdiff.roots))
drt_SVC10 = 1/min(abs(SVC10_ARdiff.roots))
drt_SVC11 = 1/min(abs(SVC11_ARdiff.roots))
drt_SVC12 = 1/min(abs(SVC12_ARdiff.roots))
drt_SVC13 = 1/min(abs(SVC13_ARdiff.roots))
drt_SVC14 = 1/min(abs(SVC14_ARdiff.roots))

drt_SVC = [drt_SVC1, drt_SVC2, drt_SVC3, drt_SVC4, drt_SVC5,
          drt_SVC6, drt_SVC7, drt_SVC8, drt_SVC9, drt_SVC10,
          drt_SVC11, drt_SVC12, drt_SVC13, drt_SVC14]
print(drt_SVC)


model_SVA1_diff = AutoReg(SV_A1_diff, 2)
SVA1_ARdiff = model_SVA1_diff.fit()

model_SVA2_diff = AutoReg(SV_A2_diff, 2)
SVA2_ARdiff = model_SVA2_diff.fit()

model_SVA3_diff = AutoReg(SV_A3_diff, 2)
SVA3_ARdiff = model_SVA3_diff.fit()

model_SVA4_diff = AutoReg(SV_A4_diff, 2)
SVA4_ARdiff = model_SVA4_diff.fit()

model_SVA5_diff = AutoReg(SV_A2_diff, 2)
SVA5_ARdiff = model_SVA5_diff.fit()

model_SVA6_diff = AutoReg(SV_A6_diff, 2)
SVA6_ARdiff = model_SVA6_diff.fit()

model_SVA7_diff = AutoReg(SV_A7_diff, 2)
SVA7_ARdiff = model_SVA7_diff.fit()

model_SVA8_diff = AutoReg(SV_A8_diff, 2)
SVA8_ARdiff = model_SVA8_diff.fit()

model_SVA9_diff = AutoReg(SV_A9_diff, 2)
SVA9_ARdiff = model_SVA9_diff.fit()

model_SVA10_diff = AutoReg(SV_A10_diff, 2)
SVA10_ARdiff = model_SVA10_diff.fit()

# Raices minimas
drt_SVA1 = 1/min(abs(SVA1_ARdiff.roots))
drt_SVA2 = 1/min(abs(SVA2_ARdiff.roots))
drt_SVA3 = 1/min(abs(SVA3_ARdiff.roots))
drt_SVA4 = 1/min(abs(SVA4_ARdiff.roots))
drt_SVA5 = 1/min(abs(SVA5_ARdiff.roots))
drt_SVA6 = 1/min(abs(SVA6_ARdiff.roots))
drt_SVA7 = 1/min(abs(SVA7_ARdiff.roots))
drt_SVA8 = 1/min(abs(SVA8_ARdiff.roots))
drt_SVA9 = 1/min(abs(SVA9_ARdiff.roots))
drt_SVA10 = 1/min(abs(SVA10_ARdiff.roots))


drt_SVA = [drt_SVA1, drt_SVA2, drt_SVA3, drt_SVA4, drt_SVA5,
          drt_SVA6, drt_SVA7, drt_SVA8, drt_SVA9, drt_SVA10]
print(drt_SVA)


m1 = [np.mean(drt_SVC),np.mean(drt_SVA)]
d1 = [np.std(drt_SVC),np.std(drt_SVA)]
e1 = [d1[0]/np.sqrt(14), d1[1]/np.sqrt(10)]

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.style.use('seaborn-whitegrid')


index = np.arange(2)
width = 0.7
labels = ('Controls', 'Ang_II')

fig, ax = plt.subplots()
ax.p1 = plt.bar(index, m1, width=width, color="blue",
               linewidth=2, zorder=5, alpha=0.5)
ax.errs = plt.errorbar(index, m1, yerr=e1, fmt='.k')

plt.xticks(index, labels)

plt.ylabel('Average of Maximum Dynamic Response Time SV')
plt.show()

pg.ttest(x = drt_SVC, y = drt_SVA, paired=False, alternative='two-sided', correction='auto', confidence=0.95)
# Out:
# [0.6558737086367714, 0.8262402894713172, 0.08486624153493165, 0.44739721521108183, 0.8262402894713172, 0.6532661885551219, 0.5878986128443576, 0.7224520363750029, 0.7286054916645681, 0.3989079499901849, 0.6097233319981791, 0.5077097864539982, 0.4937161266903166, 0.9462190792012266]
# [0.38904267186520736, 0.4052734363005071, 0.6081065175417733, 0.6983437592078612, 0.4052734363005071, 0.656174659710918, 0.3578152300678534, 0.68582647517855, 0.6522562548679299, 0.997567655163633]
# C:\Users\rio\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\rio\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
